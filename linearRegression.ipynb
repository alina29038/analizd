# %%
from sklearn import datasets
from sklearn.datasets import load_boston
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
data = datasets.load_boston()
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function load_boston is deprecated; `load_boston` is deprecated in 1.0 and will be removed in 1.2.
#
#     The Boston housing prices dataset has an ethical problem. You can refer to
#     the documentation of this function for further details.
#
#     The scikit-learn maintainers therefore strongly discourage the use of this
#     dataset unless the purpose of the code is to study and educate about
#     ethical issues in data science and machine learning.
#
#     In this special case, you can fetch the dataset from the original
#     source::
#
#         import pandas as pd
#         import numpy as np
#
#
#         data_url = "http://lib.stat.cmu.edu/datasets/boston"
#         raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
#         data = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
#         target = raw_df.values[1::2, 2]
#
# ...

# %%
df = pd.DataFrame(data.data, columns=data.feature_names)
df['PRICE'] = data.target
df1 = df.drop(columns = ['CRIM','ZN','INDUS','CHAS','NOX','RM', 'AGE','DIS', 'RAD', 'TAX', 'PTRATIO', 'B'])
df1.head()
# Out:
#    LSTAT  PRICE
# 0   4.98   24.0
# 1   9.14   21.6
# 2   4.03   34.7
# 3   2.94   33.4
# 4   5.33   36.2

# %%
y = df1['PRICE']
X = df1['LSTAT']
X = X.values.reshape(-1, 1)
y = y.values.reshape(-1, 1)

lreg = LinearRegression()
lreg.fit(X,y)

X_pred = lreg.predict(X)
lreg.score(X,y)
# Out:
# 0.5441462975864797

# %%
Xn = len(X)
i = 0
Xsr = 0
for j in range(Xn):
  Xsr += df1.iloc[i]['LSTAT']
  i+=1
Xsr = Xsr/Xn
print('Xsr: ',Xsr)

Yn = len(y)
i = 0
Ysr = 0
for j in range(Yn):
  Ysr += df1.iloc[i]['PRICE']
  i+=1
Ysr = Ysr/Yn
print('Ysr: ',Ysr)
# Out:
# Xsr:  12.653063241106723
# Ysr:  22.532806324110698

# %%
Xst2 = 0
i = 0
for i in range(Xn):
  Xst2 += (df1.iloc[i]['LSTAT'] - Xsr) ** 2
  i+=1
Xst2 = Xst2/Xn
Xst2 = Xst2 ** 0.5
print('Xst2: ',Xst2)

Yst2 = 0
i = 0
for i in range(Yn):
  Yst2 += (df1.iloc[i]['PRICE'] - Ysr) ** 2
  i+=1
Yst2 = Yst2/Yn
Yst2 = Yst2 ** 0.5
print('Yst2: ',Yst2)
# Out:
# Xst2:  7.134001636650485
# Yst2:  9.188011545278206

# %%
i = 0
xysr = 0
for i in range(Xn):
  xysr += df1.iloc[i]['LSTAT'] * df1.iloc[i]['PRICE']
  i+=1
xysr= xysr/Xn
coefcorr = (xysr - Xsr * Ysr) / (Xst2 * Yst2)
print('coefcorr' ,coefcorr)
# Out:
# coefcorr -0.737662726174022

# %%
a = (coefcorr * Yst2) / Xst2
b = Ysr - a * Xsr
print('a: ',a)
print('b: ',b)
# Out:
# a:  -0.9500493537580004
# b:  34.55384087938325

# %%
r2 = coefcorr  ** 2
print('r2: ',r2)
# Out:
# r2:  0.5441462975864901

# %%
i = 0
for i in range(Xn):
  y2 =  a * df1.iloc[i]['LSTAT'] + b
  print(y2)
# Out:
# 29.822595097668408
# 25.870389786035126
# 30.72514198373851
# 31.760695779334732
# 29.49007782385311
# 29.60408374630407
# 22.744727412171308
# 16.360395754917548
# 6.118863721406299
# 18.307996930121444
# 15.125331595032144
# 21.946685955014587
# 19.628565531845066
# 26.70643321734217
# 24.80633450982617
# 26.506922853052988
# 28.302516131655608
# 20.616616859753385
# 23.447763933952228
# 23.83728416899301
# 14.583803463390083
# 21.414658316910106
# 16.768916977033484
# 15.666859726674204
# 19.068036413127842
# 18.868526048838664
# 20.483609950227265
# 18.136988046445005
# 22.393209151280846
# 23.172249621362408
# 13.082725484452443
# 22.16519730637893
# 8.227973286749062
# 17.120435237923942
# 15.229837023945525
# 25.35736313500581
# 23.713777753004468
# 26.22190804692559
# 24.92984092581471
# 30.44962767114869
# 32.67274315894241
# 29.95560200719453
# 29.03405413404927
# 27.485473687423728
# 25.48086955099435
# 24.853836977514067
# 21.110642523707547
# 16.692913028732843
# ...

# %%
columns = []
for i in df:
  if i != 'PRICE':
    columns.append(i)
print(columns)
# Out:
# ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT']

# %%
meanX = []
for m in df.columns:
  print(m)
  Xsr = 0
  for j in range(len(df[m])):  
    Xsr += df.iloc[j][m]
  Xsr = Xsr/ len(df[m])
  meanX.append(Xsr)
  print('Xsr: ',Xsr)
  meanY = meanX
print(meanX)
print(meanY)
# Out:
# CRIM
# Xsr:  3.6135235573122535
# ZN
# Xsr:  11.363636363636363
# INDUS
# Xsr:  11.136778656126504
# CHAS
# Xsr:  0.0691699604743083
# NOX
# Xsr:  0.5546950592885372
# RM
# Xsr:  6.284634387351787
# AGE
# Xsr:  68.57490118577078
# DIS
# Xsr:  3.795042687747034
# RAD
# Xsr:  9.549407114624506
# TAX
# Xsr:  408.2371541501976
# PTRATIO
# Xsr:  18.455533596837967
# B
# Xsr:  356.67403162055257
# LSTAT
# Xsr:  12.653063241106723
# PRICE
# Xsr:  22.532806324110698
# [3.6135235573122535, 11.363636363636363, 11.136778656126504, 0.0691699604743083, 0.5546950592885372, 6.284634387351787, 68.57490118577078, 3.795042687747034, 9.549407114624506, 408.2371541501976, 18.455533596837967, 356.67403162055257, 12.653063241106723, 22.532806324110698]
# ...

# %%
stdX = []
i = 0
for m in df.columns:
  print(m)
  Xst2 = 0
  for q in range(len(df[m])):
    Xst2 += (df.iloc[q][m] - meanX[i]) ** 2
  Xst2 = Xst2/len(df[m])
  Xst2 = Xst2 ** 0.5
  print('Xst2: ',Xst2)
  stdX.append(Xst2)
  i+= 1
  stdY = stdX
print(stdX)
print(stdY)
# Out:
# CRIM
# Xst2:  8.593041351295769
# ZN
# Xst2:  23.299395694766027
# INDUS
# Xst2:  6.853570583390873
# CHAS
# Xst2:  0.25374293496034855
# NOX
# Xst2:  0.11576311540656153
# RM
# Xst2:  0.7019225143345692
# AGE
# Xst2:  28.121032570236885
# DIS
# Xst2:  2.103628356344459
# RAD
# Xst2:  8.698651117790645
# TAX
# Xst2:  168.3704950393814
# PTRATIO
# Xst2:  2.162805191482142
# B
# Xst2:  91.20460745217272
# LSTAT
# Xst2:  7.134001636650485
# PRICE
# Xst2:  9.188011545278206
# [8.593041351295769, 23.299395694766027, 6.853570583390873, 0.25374293496034855, 0.11576311540656153, 0.7019225143345692, 28.121032570236885, 2.103628356344459, 8.698651117790645, 168.3704950393814, 2.162805191482142, 91.20460745217272, 7.134001636650485, 9.188011545278206]
# ...

# %%
df.corr()
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734
# ZN      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# INDUS    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# CHAS    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# NOX      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# RM      -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# AGE      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# DIS     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# RAD      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# TAX      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# PTRATIO  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# ...

# %%
matrix = np.random.random((14,14))

# %%
for m in df.columns:
  i = 0
  j = 0
  xysr = 0
  for n in df.columns:
    print(m)
    print(n)
    for t in range(len(df[m])):
      xysr += df.iloc[t][m] * df.iloc[t][n]
    xysr= xysr/506
    # print()
    coefcorr = (xysr - meanX[i] * meanX[j]) / (stdX[i] * stdX[j])
    print('coefcorr' ,coefcorr)
    j+=1
  i+=1
# Out:
# CRIM
# CRIM
# coefcorr 1.0000000000000002
# CRIM
# ZN
# coefcorr -0.19961145674621233
# CRIM
# INDUS
# coefcorr 0.40662025804353186
# CRIM
# CHAS
# coefcorr 0.0022888187070294894
# CRIM
# NOX
# coefcorr 0.42147819656794483
# CRIM
# RM
# coefcorr -0.218452580764538
# CRIM
# AGE
# coefcorr 0.3529092047993649
# CRIM
# DIS
# coefcorr -0.34325539083488094
# CRIM
# RAD
# coefcorr 0.6257036676548138
# CRIM
# TAX
# coefcorr 0.5828753328400513
# CRIM
# PTRATIO
# coefcorr 0.5364869848360047
# CRIM
# B
# coefcorr -0.3848706314686911
# CRIM
# LSTAT
# coefcorr 0.48744748480401
# CRIM
# PRICE
# coefcorr -0.3864121518559761
# ZN
# CRIM
# coefcorr -0.16429040584820653
# ZN
# ZN
# coefcorr 3.1513147093298124
# ZN
# INDUS
# coefcorr 0.04067541190431397
# ZN
# CHAS
# coefcorr 0.1687357434067056
# ZN
# NOX
# coefcorr 2.9221012237054227
# ZN
# RM
# coefcorr 8.922723996807443
# ZN
# AGE
# coefcorr 0.6557210833044864
# ZN
# DIS
# coefcorr 3.4729878159220586
# ZN
# RAD
# coefcorr 0.14631393512371935
# ZN
# ...

# %%
matrix[0,0] = coefcorr
print(matrix)
# Out:
# [[6.47505115 0.41873623 0.39262052 0.63903074 0.20176965 0.77749951
#   0.94400993 0.51525175 0.45419405 0.02723142 0.3689914  0.93366885
#   0.84711232 0.82917854]
#  [0.45274409 0.73360936 0.42031876 0.96223785 0.54532246 0.60251667
#   0.75426107 0.1046708  0.38063778 0.81099846 0.34046857 0.83298946
#   0.09472471 0.44002127]
#  [0.92437196 0.15143841 0.38189823 0.36186819 0.7853049  0.09095743
#   0.59196    0.90233331 0.65427628 0.72686255 0.16931721 0.19874419
#   0.57952933 0.06533137]
#  [0.49712988 0.21087381 0.41959019 0.57282594 0.57095683 0.48041529
#   0.90523198 0.65959643 0.87347564 0.98539159 0.02376917 0.67436675
#   0.1793337  0.06424597]
#  [0.84138833 0.39107734 0.88593157 0.73392287 0.07017524 0.40088738
#   0.40538878 0.94424768 0.78034785 0.08567651 0.0448905  0.95574878
#   0.01881603 0.92580885]
#  [0.75478331 0.67532876 0.60655591 0.91975046 0.22483759 0.93601798
#   0.22909845 0.16310477 0.99892694 0.33180195 0.85384831 0.90407157
# ...

# %%
X = df[['RM', 'LSTAT']]
y = df['PRICE']
X = X.values.reshape(-1, 1)
y = y.values.reshape(-1, 1)
mnLreg = LinearRegression()
mnLreg.fit(X, y)
X_pred = mnLreg.predict(X)
mnLreg.score(X, y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-b5313411474b> in <module>
#       6 # X2 = df['RM']
#       7 mnLreg = LinearRegression()
# ----> 8 mnLreg.fit(X, y)
#       9 X_pred = mnLreg.predict(X)
#      10 mnLreg.score(X, y)
#
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_base.py in fit(self, X, y, sample_weight)
#     660         accept_sparse = False if self.positive else ["csr", "csc", "coo"]
#     661
# --> 662         X, y = self._validate_data(
#     663             X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     664         )
#
# /usr/local/lib/python3.8/dist-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     579                 y = check_array(y, **check_y_params)
#     580             else:
# ...

# %%
X1= df['LSTAT']
X2 = df['RM']
