# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mpl

# %%
df = pd.read_csv('train.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.info()
df.nunique()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
# PassengerId    891
# Survived         2
# Pclass           3
# Name           891
# Sex              2
# Age             88
# SibSp            7
# Parch            7
# Ticket         681
# Fare           248
# Cabin          147
# Embarked         3
# dtype: int64

# %%
df.shape
# Out:
# (891, 12)

# %%
df = df.drop_duplicates()
df.shape
# Out:
# (891, 12)

# %%
df.isnull().mean() * 100
# Out:
# PassengerId     0.000000
# Survived        0.000000
# Pclass          0.000000
# Name            0.000000
# Sex             0.000000
# Age            19.865320
# SibSp           0.000000
# Parch           0.000000
# Ticket          0.000000
# Fare            0.000000
# Cabin          77.104377
# Embarked        0.224467
# dtype: float64

# %%
df.drop(columns = ['Cabin'])
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Embarked
# 0        0         A/5 21171   7.2500        S
# 1        0          PC 17599  71.2833        C
# 2        0  STON/O2. 3101282   7.9250        S
# 3        0            113803  53.1000        S
# 4        0            373450   8.0500        S
# ..     ...               ...      ...      ...
# 886      0            211536  13.0000        S
# 887      0            112053  30.0000        S
# 888      2        W./C. 6607  23.4500        S
# 889      0            111369  30.0000        C
# 890      0            370376   7.7500        Q
#
# [891 rows x 11 columns]

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.corr()
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
sns.set_style('darkgrid')
sns.countplot(y='Survived',data=df,palette='colorblind')
plt.xlabel('Количество')
plt.show()

# %%
sns.set_style('darkgrid')
sns.countplot(y='Pclass',data=df,palette='colorblind')
plt.xlabel('Количество')
plt.show()

# %%
y=df['Survived']
x=df[['SibSp','Pclass','Fare']]

# %%
from sklearn import tree
model=tree.DecisionTreeClassifier(criterion="entropy")
model.fit(x,y)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
model.score(x,y)
# Out:
# 0.8305274971941639

# %%
tree.plot_tree(model)
# Out:
# [Text(0.463422087585034, 0.9761904761904762, 'X[1] <= 2.5\nentropy = 0.961\nsamples = 891\nvalue = [549, 342]'),
#  Text(0.16632121598639457, 0.9285714285714286, 'X[2] <= 13.646\nentropy = 0.99\nsamples = 400\nvalue = [177, 223]'),
#  Text(0.034013605442176874, 0.8809523809523809, 'X[2] <= 7.75\nentropy = 0.903\nsamples = 94\nvalue = [64, 30]'),
#  Text(0.027210884353741496, 0.8333333333333334, 'entropy = 0.0\nsamples = 12\nvalue = [12, 0]'),
#  Text(0.04081632653061224, 0.8333333333333334, 'X[0] <= 0.5\nentropy = 0.947\nsamples = 82\nvalue = [52, 30]'),
#  Text(0.034013605442176874, 0.7857142857142857, 'X[2] <= 13.25\nentropy = 0.954\nsamples = 80\nvalue = [50, 30]'),
#  Text(0.027210884353741496, 0.7380952380952381, 'X[2] <= 11.75\nentropy = 0.959\nsamples = 76\nvalue = [47, 29]'),
#  Text(0.013605442176870748, 0.6904761904761905, 'X[2] <= 11.0\nentropy = 0.931\nsamples = 26\nvalue = [17, 9]'),
#  Text(0.006802721088435374, 0.6428571428571429, 'entropy = 0.954\nsamples = 24\nvalue = [15, 9]'),
#  Text(0.02040816326530612, 0.6428571428571429, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.04081632653061224, 0.6904761904761905, 'X[2] <= 12.137\nentropy = 0.971\nsamples = 50\nvalue = [30, 20]'),
#  Text(0.034013605442176874, 0.6428571428571429, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.047619047619047616, 0.6428571428571429, 'X[2] <= 12.312\nentropy = 0.963\nsamples = 49\nvalue = [30, 19]'),
#  Text(0.04081632653061224, 0.5952380952380952, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.05442176870748299, 0.5952380952380952, 'X[2] <= 12.438\nentropy = 0.968\nsamples = 48\nvalue = [29, 19]'),
#  Text(0.047619047619047616, 0.5476190476190477, 'entropy = 0.918\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.061224489795918366, 0.5476190476190477, 'X[2] <= 12.587\nentropy = 0.956\nsamples = 45\nvalue = [28, 17]'),
#  Text(0.05442176870748299, 0.5, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.06802721088435375, 0.5, 'X[2] <= 12.762\nentropy = 0.962\nsamples = 44\nvalue = [27, 17]'),
#  Text(0.061224489795918366, 0.4523809523809524, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.07482993197278912, 0.4523809523809524, 'X[2] <= 12.938\nentropy = 0.952\nsamples = 43\nvalue = [27, 16]'),
#  Text(0.06802721088435375, 0.40476190476190477, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.08163265306122448, 0.40476190476190477, 'entropy = 0.959\nsamples = 42\nvalue = [26, 16]'),
#  Text(0.04081632653061224, 0.7380952380952381, 'entropy = 0.811\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.047619047619047616, 0.7857142857142857, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.29862882653061223, 0.8809523809523809, 'X[2] <= 52.277\nentropy = 0.95\nsamples = 306\nvalue = [113, 193]'),
#  Text(0.14625850340136054, 0.8333333333333334, 'X[0] <= 1.5\nentropy = 0.993\nsamples = 171\nvalue = [77, 94]'),
#  Text(0.13945578231292516, 0.7857142857142857, 'X[2] <= 13.931\nentropy = 0.997\nsamples = 165\nvalue = [77, 88]'),
#  Text(0.1326530612244898, 0.7380952380952381, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.14625850340136054, 0.7380952380952381, 'X[2] <= 33.25\nentropy = 0.998\nsamples = 162\nvalue = [77, 85]'),
#  Text(0.08843537414965986, 0.6904761904761905, 'X[2] <= 14.25\nentropy = 0.991\nsamples = 124\nvalue = [55, 69]'),
#  Text(0.08163265306122448, 0.6428571428571429, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.09523809523809523, 0.6428571428571429, 'X[2] <= 14.75\nentropy = 0.989\nsamples = 123\nvalue = [54, 69]'),
#  Text(0.08843537414965986, 0.5952380952380952, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.10204081632653061, 0.5952380952380952, 'X[2] <= 15.4\nentropy = 0.992\nsamples = 121\nvalue = [54, 67]'),
#  Text(0.09523809523809523, 0.5476190476190477, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.10884353741496598, 0.5476190476190477, 'X[2] <= 20.25\nentropy = 0.987\nsamples = 118\nvalue = [51, 67]'),
#  Text(0.10204081632653061, 0.5, 'entropy = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.11564625850340136, 0.5, 'X[2] <= 22.0\nentropy = 0.994\nsamples = 112\nvalue = [51, 61]'),
#  Text(0.10204081632653061, 0.4523809523809524, 'X[0] <= 0.5\nentropy = 0.722\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.09523809523809523, 0.40476190476190477, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.10884353741496598, 0.40476190476190477, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.1292517006802721, 0.4523809523809524, 'X[2] <= 23.5\nentropy = 0.989\nsamples = 107\nvalue = [47, 60]'),
#  Text(0.12244897959183673, 0.40476190476190477, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.1360544217687075, 0.40476190476190477, 'X[2] <= 28.856\nentropy = 0.994\nsamples = 103\nvalue = [47, 56]'),
#  Text(0.0977891156462585, 0.35714285714285715, 'X[2] <= 26.775\nentropy = 1.0\nsamples = 75\nvalue = [37, 38]'),
#  Text(0.06547619047619048, 0.30952380952380953, 'X[2] <= 26.125\nentropy = 0.991\nsamples = 63\nvalue = [28, 35]'),
#  Text(0.041666666666666664, 0.2619047619047619, 'X[0] <= 0.5\nentropy = 0.999\nsamples = 37\nvalue = [19, 18]'),
#  Text(0.02806122448979592, 0.21428571428571427, 'X[2] <= 25.927\nentropy = 0.937\nsamples = 17\nvalue = [11, 6]'),
#  Text(0.021258503401360544, 0.16666666666666666, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.03486394557823129, 0.16666666666666666, 'X[2] <= 25.965\nentropy = 0.971\nsamples = 15\nvalue = [9, 6]'),
#  Text(0.02806122448979592, 0.11904761904761904, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.041666666666666664, 0.11904761904761904, 'X[1] <= 1.5\nentropy = 0.89\nsamples = 13\nvalue = [9, 4]'),
#  Text(0.03486394557823129, 0.07142857142857142, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.04846938775510204, 0.07142857142857142, 'entropy = 0.946\nsamples = 11\nvalue = [7, 4]'),
#  Text(0.055272108843537414, 0.21428571428571427, 'X[2] <= 25.0\nentropy = 0.971\nsamples = 20\nvalue = [8, 12]'),
#  Text(0.04846938775510204, 0.16666666666666666, 'entropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.06207482993197279, 0.16666666666666666, 'entropy = 0.964\nsamples = 18\nvalue = [7, 11]'),
#  Text(0.08928571428571429, 0.2619047619047619, 'X[2] <= 26.469\nentropy = 0.931\nsamples = 26\nvalue = [9, 17]'),
#  Text(0.0824829931972789, 0.21428571428571427, 'X[0] <= 0.5\nentropy = 0.684\nsamples = 11\nvalue = [2, 9]'),
#  Text(0.07568027210884354, 0.16666666666666666, 'entropy = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(0.08928571428571429, 0.16666666666666666, 'entropy = 1.0\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.
5\nentropy = 0.811\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.24489795918367346, 0.40476190476190477, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.2585034013605442, 0.40476190476190477, 'entropy = 0.918\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.2653061224489796, 0.4523809523809524, 'entropy = 0.971\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.15306122448979592, 0.7857142857142857, 'entropy = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.45099914965986393, 0.8333333333333334, 'X[1] <= 1.5\nentropy = 0.837\nsamples = 135\nvalue = [36, 99]'),
#  Text(0.4373937074829932, 0.7857142857142857, 'X[2] <= 52.827\nentropy = 0.799\nsamples = 128\nvalue = [31, 97]'),
#  Text(0.43059098639455784, 0.7380952380952381, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.44419642857142855, 0.7380952380952381, 'X[2] <= 387.665\nentropy = 0.808\nsamples = 125\nvalue = [31, 94]'),
#  Text(0.4373937074829932, 0.6904761904761905, 'X[2] <= 211.419\nentropy = 0.818\nsamples = 122\nvalue = [31, 91]'),
#  Text(0.4053996598639456, 0.6428571428571429, 'X[2] <= 159.165\nentropy = 0.781\nsamples = 108\nvalue = [25, 83]'),
#  Text(0.3985969387755102, 0.5952380952380952, 'X[2] <= 149.035\nentropy = 0.8\nsamples = 103\nvalue = [25, 78]'),
#  Text(0.36181972789115646, 0.5476190476190477, 'X[2] <= 116.638\nentropy = 0.777\nsamples = 96\nvalue = [22, 74]'),
#  Text(0.32227891156462585, 0.5, 'X[0] <= 1.5\nentropy = 0.816\nsamples = 83\nvalue = [21, 62]'),
#  Text(0.31547619047619047, 0.4523809523809524, 'X[2] <= 79.825\nentropy = 0.801\nsamples = 82\nvalue = [20, 62]'),
#  Text(0.272108843537415, 0.40476190476190477, 'X[2] <= 60.288\nentropy = 0.863\nsamples = 49\nvalue = [14, 35]'),
#  Text(0.25510204081632654, 0.35714285714285715, 'X[2] <= 56.415\nentropy = 0.672\nsamples = 17\nvalue = [3, 14]'),
#  Text(0.24829931972789115, 0.30952380952380953, 'X[0] <= 0.5\nentropy = 0.881\nsamples = 10\nvalue = [3, 7]'),
#  Text(0.24149659863945577, 0.2619047619047619, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.25510204081632654, 0.2619047619047619, 'X[2] <= 55.671\nentropy = 0.954\nsamples = 8\nvalue = [3, 5]'),
#  Text(0.24829931972789115, 0.21428571428571427, 'X[2] <= 54.271\nentropy = 0.918\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.24149659863945577, 0.16666666666666666, 'entropy = 0.971\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.25510204081632654, 0.16666666666666666, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.2619047619047619, 0.21428571428571427, 'entropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.2619047619047619, 0.30952380952380953, 'entropy = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(0.2891156462585034, 0.35714285714285715, 'X[2] <= 62.669\nentropy = 0.928\nsamples = 32\nvalue = [11, 21]'),
#  Text(0.282312925170068, 0.30952380952380953, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.29591836734693877, 0.30952380952380953, 'X[2] <= 77.008\nentropy = 0.85\nsamples = 29\nvalue = [8, 21]'),
#  Text(0.282312925170068, 0.2619047619047619, 'X[2] <= 71.142\nentropy = 0.619\nsamples = 13\nvalue = [2, 11]'),
#  Text(0.2755102040816326, 0.21428571428571427, 'X[0] <= 0.5\nentropy = 0.863\nsamples = 7\nvalue = [2, 5]'),
#  Text(0.2687074829931973, 0.16666666666666666, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.282312925170068, 0.16666666666666666, 'X[2] <= 68.8\nentropy = 0.918\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.2755102040816326, 0.11904761904761904, 'entropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.2891156462585034, 0.11904761904761904, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.2891156462585034, 0.21428571428571427, 'entropy = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.30952380952380953, 0.2619047619047619, 'X[2] <= 77.623\nentropy = 0.954\nsamples = 16\nvalue = [6, 10]'),
#  Text(0.30272108843537415, 0.21428571428571427, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.3163265306122449, 0.21428571428571427, 'X[2] <= 78.558\nentropy = 0.863\nsamples = 14\nvalue = [4, 10]'),
#  Text(0.30952380952380953, 0.16666666666666666, 'entropy = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.3231292517006803, 0.16666666666666666, 'X[2] <= 79.425\nentropy = 0.991\nsamples = 9\nvalue = [4, 5]'),
#  Text(0.30612244897959184, 0.11904761904761904, 'X[2] <= 79.025\nentropy = 1.0\nsamples = 6\nvalue = [3, 3]'),
#  Text(0
nsamples = 30\nvalue = [28, 2]'),
#  Text(0.5595238095238095, 0.7857142857142857, 'X[2] <= 6.962\nentropy = 0.544\nsamples = 16\nvalue = [14, 2]'),
#  Text(0.5527210884353742, 0.7380952380952381, 'X[2] <= 2.006\nentropy = 0.371\nsamples = 14\nvalue = [13, 1]'),
#  Text(0.5459183673469388, 0.6904761904761905, 'entropy = 0.811\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.5595238095238095, 0.6904761904761905, 'entropy = 0.0\nsamples = 10\nvalue = [10, 0]'),
#  Text(0.5663265306122449, 0.7380952380952381, 'entropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.5731292517006803, 0.7857142857142857, 'entropy = 0.0\nsamples = 14\nvalue = [14, 0]'),
#  Text(0.6509353741496599, 0.8333333333333334, 'X[2] <= 7.883\nentropy = 0.757\nsamples = 298\nvalue = [233, 65]'),
#  Text(0.5867346938775511, 0.7857142857142857, 'X[2] <= 7.877\nentropy = 0.867\nsamples = 142\nvalue = [101, 41]'),
#  Text(0.5799319727891157, 0.7380952380952381, 'X[2] <= 7.183\nentropy = 0.839\nsamples = 138\nvalue = [101, 37]'),
#  Text(0.5731292517006803, 0.6904761904761905, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5867346938775511, 0.6904761904761905, 'X[2] <= 7.731\nentropy = 0.831\nsamples = 137\nvalue = [101, 36]'),
#  Text(0.5408163265306123, 0.6428571428571429, 'X[0] <= 0.5\nentropy = 0.715\nsamples = 56\nvalue = [45, 11]'),
#  Text(0.5340136054421769, 0.5952380952380952, 'X[2] <= 7.24\nentropy = 0.737\nsamples = 53\nvalue = [42, 11]'),
#  Text(0.5170068027210885, 0.5476190476190477, 'X[2] <= 7.227\nentropy = 0.855\nsamples = 25\nvalue = [18, 7]'),
#  Text(0.5102040816326531, 0.5, 'entropy = 0.811\nsamples = 12\nvalue = [9, 3]'),
#  Text(0.5238095238095238, 0.5, 'entropy = 0.89\nsamples = 13\nvalue = [9, 4]'),
#  Text(0.5510204081632653, 0.5476190476190477, 'X[2] <= 7.404\nentropy = 0.592\nsamples = 28\nvalue = [24, 4]'),
#  Text(0.5374149659863946, 0.5, 'X[2] <= 7.281\nentropy = 0.391\nsamples = 13\nvalue = [12, 1]'),
#  Text(0.5306122448979592, 0.4523809523809524, 'entropy = 0.414\nsamples = 12\nvalue = [11, 1]'),
#  Text(0.54421768707483, 0.4523809523809524, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.564625850340136, 0.5, 'X[2] <= 7.688\nentropy = 0.722\nsamples = 15\nvalue = [12, 3]'),
#  Text(0.5578231292517006, 0.4523809523809524, 'X[2] <= 7.508\nentropy = 0.779\nsamples = 13\nvalue = [10, 3]'),
#  Text(0.5510204081632653, 0.40476190476190477, 'entropy = 0.918\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.564625850340136, 0.40476190476190477, 'X[2] <= 7.535\nentropy = 0.722\nsamples = 10\nvalue = [8, 2]'),
#  Text(0.5578231292517006, 0.35714285714285715, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.5714285714285714, 0.35714285714285715, 'X[2] <= 7.59\nentropy = 0.764\nsamples = 9\nvalue = [7, 2]'),
#  Text(0.564625850340136, 0.30952380952380953, 'entropy = 0.811\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.5782312925170068, 0.30952380952380953, 'X[2] <= 7.64\nentropy = 0.722\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.5714285714285714, 0.2619047619047619, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.5850340136054422, 0.2619047619047619, 'entropy = 0.811\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.5714285714285714, 0.4523809523809524, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.5476190476190477, 0.5952380952380952, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.6326530612244898, 0.6428571428571429, 'X[2] <= 7.763\nentropy = 0.892\nsamples = 81\nvalue = [56, 25]'),
#  Text(0.6122448979591837, 0.5952380952380952, 'X[0] <= 0.5\nentropy = 0.947\nsamples = 41\nvalue = [26, 15]'),
#  Text(0.6054421768707483, 0.5476190476190477, 'X[2] <= 7.74\nentropy = 0.954\nsamples = 40\nvalue = [25, 15]'),
#  Text(0.5918367346938775, 0.5, 'X[2] <= 7.735\nentropy = 1.0\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.5850340136054422, 0.4523809523809524, 'entropy = 1.0\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.5986394557823129, 0.4523809523809524, 'entropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.6190476190476191, 0.5, 'X[2] <= 7.746\nentropy = 0.937\nsamples = 34\nvalue = [22, 12]'),
#  Text(0.6122448979591837, 0.4523809523809524, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6258503401360545, 0.4523809523809524, 'entropy = 0.946\nsamples = 33\nvalue = [21, 12]'),
#  Text(0.6190476190476191, 0.5476190476190477, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6530612244897959, 0.5952380952380952, 'X[0] <= 0.5\nentropy = 0.811\nsamples = 40\nvalue = [30, 10]'),
#  Text(0.6394557823129252, 0.5476190476190477, 'X[2] <= 7.781\nentropy = 0.776\nsamples = 35\nvalue = [27, 8]'),
#  Text(0.6326530612244898, 0.5, 'entropy = 0.592\nsamples = 14\nvalue = [12, 2]'),
#  Text(0.6462585034013606, 0.5, 'X[2] <= 7.792\nentropy = 0.863\nsamples = 21\nvalue = [15, 6]'),
#  Text(0.6394557823129252, 0.4523809523809524, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6530612244897959, 0.4523809523809524, 'X[2] <= 7.842\nentropy = 0.811\nsamples = 20\nvalue = [15, 5]'),
#  Text(0.6394557823129252, 0.40476190476190477, 'X[2] <= 7.815\nentropy = 0.918\nsamples = 9\nvalue = [6, 3]'),
#  Text(0.6326530612244898, 0.35714285714285715, 'X[2] <= 7.798\nentropy = 0.863\nsamples = 7\nvalue = [5, 2]'),
#  Text(0.6258503401360545, 0.30952380952380953, 'entropy = 0.918\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.6394557823129252, 0.30952380952380953, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6462585034013606, 0.35714285714285715, 'entropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.6666666666666666, 0.40476190476190477, 'X[2] <= 7.865\nentropy = 0.684\nsamples = 11\nvalue = [9, 2]'),
#  Text(0.6598639455782312, 0.35714285714285715, 'entropy = 0.722\nsamples = 10\nvalue = [8, 2]'),
#  Text(0.673469387755102, 0.35714285714285715, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6666666666666666, 0.5476190476190477, 'X[2] <= 7.815\nentropy = 0.971\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.6598639455782312, 0.5, 'entropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.673469387755102, 0.5, 'entropy = 0.918\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.5935374149659864, 0.7380952380952381, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.7151360544217688, 0.7857142857142857, 'X[2] <= 7.91\nentropy = 0.619\nsamples = 156\nvalue = [132, 24]'),
#  Text(0.6938775510204082, 0.7380952380952381, 'X[2] <= 7.892\nentropy = 0.172\nsamples = 39\nvalue = [38, 1]'),
#  Text(0.6870748299319728, 0.6904761904761905, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7006802721088435, 0.6904761904761905, 'entropy = 0.176\nsamples = 38\nvalue = [37, 1]'),
#  Text(0.7363945578231292, 0.7380952380952381, 'X[2] <= 8.04\nentropy = 0.715\nsamples = 117\nvalue = [94, 23]'),
#  Text(0.7142857142857143, 0.6904761904761905, 'X[0] <= 3.0\nentropy = 0.998\nsamples = 19\nvalue = [10, 9]'),
#  Text(0.7074829931972789, 0.6428571428571429, 'X[0] <= 1.5\nentropy = 0.991\nsamples = 18\nvalue = [10, 8]'),
#  Text(0.7006802721088435, 0.5952380952380952, 'X[2] <= 7.977\nentropy = 1.0\nsamples = 16\nvalue = [8, 8]'),
#  Text(0.6938775510204082, 0.5476190476190477, 'X[0] <= 0.5\nentropy = 0.997\nsamples = 15\nvalue = [8, 7]'),
#  Text(0.6870748299319728, 0.5, 'entropy = 0.996\nsamples = 13\nvalue = [7, 6]'),
#  Text(0.7006802721088435, 0.5, 'entropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.7074829931972789, 0.5476190476190477, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.7142857142857143, 0.5952380952380952, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.7210884353741497, 0.6428571428571429, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.7585034013605442, 0.6904761904761905, 'X[0] <= 0.5\nentropy = 0.592\nsamples = 98\nvalue = [84, 14]'),
#  Text(0.7517006802721088, 0.6428571428571429, 'X[2] <= 9.288\nentropy = 0.611\nsamples = 93\nvalue = [79, 14]'),
#  Text(0.7278911564625851, 0.5952380952380952, 'X[2] <= 8.698\nentropy = 0.539\nsamples = 73\nvalue = [64, 9]'),
#  Text(0.7210884353741497, 0.5476190476190477, 'X[2] <= 8.673\nentropy = 0.575\nsamples = 66\nvalue = [57, 9]'),
#  Text(0.7142857142857143, 0.5, 'X[2] <= 8.585\nentropy = 0.538\nsamples = 65\nvalue = [57, 8]'),
#  Text(0.7006802721088435, 0.4523809523809524, 'X[2] <= 8.487\nentropy = 0.57\nsamples = 52\nvalue = [45, 7]'),
#  Text(0.6938775510204082, 0.40476190476190477, 'X[2] <= 8.125\nentropy = 0.523\nsamples = 51\nvalue = [45, 6]'),
#  Text(0.6870748299319728, 0.35714285714285715, 'X[2] <= 8.081\nentropy = 0.575\nsamples = 44\nvalue = [38, 6]'),
#  Text(0.6802721088435374, 0.30952380952380953, 'entropy = 0.519\nsamples = 43\nvalue = [38, 5]'),
#  Text(0.6938775510204082, 0.30952380952380953, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.7006802721088435, 0.35714285714285715, 'entropy = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.7074829931972789, 0.40476190476190477, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.7278911564625851, 0.4523809523809524, 'X[2] <= 8.658\nentropy = 0.391\nsamples = 13\nvalue = [12, 1]'),
#  Text(0.7210884353741497, 0.40476190476190477, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7346938775510204, 0.40476190476190477, 'entropy = 0.414\nsamples = 12\nvalue = [11, 1]'),
#  Text(0.7278911564625851, 0.5, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.7346938775510204, 0.5476190476190477, 'entropy = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.7755102040816326, 0.5952380952380952, 'X[2] <= 9.844\nentropy = 0.811\nsamples = 20\nvalue = [15, 5]'),
#  Text(0.7687074829931972, 0.5476190476190477, 'X[2] <= 9.84\nentropy = 0.896\nsamples = 16\nvalue = [11, 5]'),
#  Text(0.7619047619047619, 0.5, 'X[2] <= 9.712\nentropy = 0.837\nsamples = 15\nvalue = [11, 4]'),
#  Text(0.7551020408163265, 0.4523809523809524, 'X[2] <= 9.417\nentropy = 0.863\nsamples = 14\nvalue = [10, 4]'),
#  Text(0.7482993197278912, 0.40476190476190477, 'entropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.7619047619047619, 0.40476190476190477, 'X[2] <= 9.544\nentropy = 0.811\nsamples = 12\nvalue = [9, 3]'),
#  Text(0.7551020408163265, 0.35714285714285715, 'X[2] <= 9.492\nentropy = 0.722\nsamples = 10\nvalue = [8, 2]'),
#  Text(0.7482993197278912, 0.30952380952380953, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7619047619047619, 0.30952380952380953, 'entropy = 0.764\nsamples = 9\nvalue = [7, 2]'),
#  Text(0.7687074829931972, 0.35714285714285715, 'entropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.7687074829931972, 0.4523809523809524, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7755102040816326, 0.5, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.782312925170068, 0.5476190476190477, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.7653061224489796, 0.6428571428571429, 'entropy = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.9124149659863946, 0.8809523809523809, 'X[2] <= 13.763\nentropy = 0.903\nsamples = 163\nvalue = [111, 52]'),
#  Text(0.9056122448979592, 0.8333333333333334, 'entropy = 0.0\nsamples = 11\nvalue = [0, 11]'),
#  Text(0.91921768707483, 0.8333333333333334, 'X[0] <= 2.5\nentropy = 0.841\nsamples = 152\nvalue = [111, 41]'),
#  Text(0.8656462585034014, 0.7857142857142857, 'X[2] <= 15.173\nentropy = 0.927\nsamples = 111\nvalue = [73, 38]'),
#  Text(0.8129251700680272, 0.7380952380952381, 'X[0] <= 0.5\nentropy = 0.297\nsamples = 19\nvalue = [18, 1]'),
#  Text(0.8061224489795918, 0.6904761904761905, 'entropy = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(0.8197278911564626, 0.6904761904761905, 'X[2] <= 14.427\nentropy = 0.469\nsamples = 10\nvalue = [9, 1]'),
#  Text(0.8129251700680272, 0.6428571428571429, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.826530612244898, 0.6428571428571429, 'X[2] <= 14.456\nentropy = 0.592\nsamples = 7\nvalue = [6, 1]'),
#  Text(0.8197278911564626, 0.5952380952380952, 'entropy = 0.722\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.8333333333333334, 0.5952380952380952, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.9183673469387755, 0.7380952380952381, 'X[2] <= 23.35\nentropy = 0.972\nsamples = 92\nvalue = [55, 37]'),
#  Text(0.8775510204081632, 0.6904761904761905, 'X[2] <= 21.852\nentropy = 0.998\nsamples = 63\nvalue = [33, 30]'),
#  Text(0.8537414965986394, 0.6428571428571429, 'X[2] <= 20.825\nentropy = 0.989\nsamples = 57\nvalue = [32, 25]'),
#  Text(0.8469387755102041, 0.5952380952380952, 'X[2] <= 16.0\nentropy = 0.994\nsamples = 55\nvalue = [30, 25]'),
#  Text(0.8061224489795918, 0.5476190476190477, 'X[2] <= 15.875\nentropy = 0.998\nsamples = 21\nvalue = [10, 11]'),
#  Text(0.7993197278911565, 0.5, 'X[2] <= 15.373\nentropy = 0.998\nsamples = 19\nvalue = [10, 9]'),
#  Text(0.782312925170068, 0.4523809523809524, 'X[0] <= 0.5\nentropy = 0.971\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.7755102040816326, 0.40476190476190477, 'entropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.7891156462585034, 0.40476190476190477, 'entropy = 0.918\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.8163265306122449, 0.4523809523809524, 'X[2] <= 15.646\nentropy = 0.985\nsamples = 14\nvalue = [8, 6]'),
#  Text(0.8027210884353742, 0.40476190476190477, 'X[2] <= 15.525\nentropy = 0.918\nsamples = 9\nvalue = [6, 3]'),
#  Text(0.7959183673469388, 0.35714285714285715, 'X[0] <= 0.5\nentropy = 0.954\nsamples = 8\nvalue = [5, 3]'),
#  Text(0.7891156462585034, 0.30952380952380953, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8027210884353742, 0.30952380952380953, 'entropy = 0.985\nsamples = 7\nvalue = [4, 3]'),
#  Text(0.8095238095238095, 0.35714285714285715, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8299319727891157, 0.40476190476190477, 'X[2] <= 15.796\nentropy = 0.971\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.8231292517006803, 0.35714285714285715, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.8367346938775511, 0.35714285714285715, 'entropy = 0.918\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.8129251700680272, 0.5, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.8877551020408163, 0.5476190476190477, 'X[2] <= 18.394\nentropy = 0.977\nsamples = 34\nvalue = [20, 14]'),
#  Text(0.8707482993197279, 0.5, 'X[2] <= 17.6\nentropy = 0.874\nsamples = 17\nvalue = [12, 5]'),
#  Text(0.8639455782312925, 0.4523809523809524, 'X[2] <= 16.4\nentropy = 0.98\nsamples = 12\nvalue = [7, 5]'),
#  Text(0.8571428571428571, 0.40476190476190477, 'X[0] <= 0.5\nentropy = 0.764\nsamples = 9\nvalue = [7, 2]'),
#  Text(0.8503401360544217, 0.35714285714285715, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.8639455782312925, 0.35714285714285715, 'entropy = 0.918\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.8707482993197279, 0.40476190476190477, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.8775510204081632, 0.4523809523809524, 'entropy = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.9047619047619048, 0.5, 'X[0] <= 1.5\nentropy = 0.998\nsamples = 17\nvalue = [8, 9]'),
#  Text(0.8979591836734694, 0.4523809523809524, 'X[2] <= 20.231\nentropy = 0.985\nsamples = 14\nvalue = [8, 6]'),
#  Text(0.8843537414965986, 0.40476190476190477, 'X[2] <= 19.613\nentropy = 0.863\nsamples = 7\nvalue = [5, 2]'),
#  Text(0.8775510204081632, 0.35714285714285715, 'X[2] <= 19.023\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.8707482993197279, 0.30952380952380953, 'entropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.8843537414965986, 0.30952380952380953, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.891156462585034, 0.35714285714285715, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.9115646258503401, 0.40476190476190477, 'X[0] <= 0.5\nentropy = 0.985\nsamples = 7\nvalue = [3, 4]'),
#  Text(0.9047619047619048, 0.35714285714285715, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9183673469387755, 0.35714285714285715, 'X[2] <= 20.387\nentropy = 1.0\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.9115646258503401, 0.30952380952380953, 'entropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.9251700680272109, 0.30952380952380953, 'X[2] <= 20.55\nentropy = 1.0\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.9183673469387755, 0.2619047619047619, 'entropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.9319727891156463, 0.2619047619047619, 'entropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.9115646258503401, 0.4523809523809524, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.8605442176870748, 0.5952380952380952, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.9013605442176871, 0.6428571428571429, 'X[2] <= 22.442\nentropy = 0.65\nsamples = 6\nvalue = [1, 5]'),
#  Text(0.8945578231292517, 0.5952380952380952, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.9081632653061225, 0.5952380952380952, 'X[2] <= 22.887\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.9013605442176871, 0.5476190476190477, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9149659863945578, 0.5476190476190477, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.9591836734693877, 0.6904761904761905, 'X[2] <= 51.698\nentropy = 0.797\nsamples = 29\nvalue = [22, 7]'),
#  Text(0.9523809523809523, 0.6428571428571429, 'X[2] <= 32.881\nentropy = 0.439\nsamples = 22\nvalue = [20, 2]'),
#  Text(0.9455782312925171, 0.5952380952380952, 'X[2] <= 31.331\nentropy = 0.544\nsamples = 16\nvalue = [14, 2]'),
#  Text(0.9387755102040817, 0.5476190476190477, 'X[2] <= 26.025\nentropy = 0.353\nsamples = 15\nvalue = [14, 1]'),
#  Text(0.9319727891156463, 0.5, 'X[0] <= 0.5\nentropy = 0.469\nsamples = 10\nvalue = [9, 1]'),
#  Text(0.9251700680272109, 0.4523809523809524, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.9387755102040817, 0.4523809523809524, 'X[2] <= 23.8\nentropy = 0.592\nsamples = 7\nvalue = [6, 1]'),
#  Text(0.9319727891156463, 0.40476190476190477, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.9455782312925171, 0.40476190476190477, 'X[0] <= 1.5\nentropy = 0.722\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.9387755102040817, 0.35714285714285715, 'entropy = 0.811\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.9523809523809523, 0.35714285714285715, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9455782312925171, 0.5, 'entropy = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.9523809523809523, 0.5476190476190477, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9591836734693877, 0.5952380952380952, 'entropy = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.9659863945578231, 0.6428571428571429, 'entropy = 0.863\nsamples = 7\nvalue = [2, 5]'),
#  Text(0.9727891156462585, 0.7857142857142857, 'X[2] <= 18.463\nentropy = 0.378\nsamples = 41\nvalue = [38, 3]'),
#  Text(0.9659863945578231, 0.7380952380952381, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9795918367346939, 0.7380952380952381, 'X[2] <= 31.331\nentropy = 0.286\nsamples = 40\nvalue = [38, 2]'),
#  Text(0.9727891156462585, 0.6904761904761905, 'entropy = 0.0\nsamples = 20\nvalue = [20, 0]'),
#  Text(0.9863945578231292, 0.6904761904761905, 'X[2] <= 35.538\nentropy = 0.469\nsamples = 20\nvalue = [18, 2]'),
#  Text(0.9795918367346939, 0.6428571428571429, 'entropy = 0.918\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.9931972789115646, 0.6428571428571429, 'entropy = 0.0\nsamples = 17\nvalue = [17, 0]')]

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
params = {'n_estimators':200,
          'max_depth':12,
          'criterion':'mse',
          'learning_rate':0.03,
          'min_samples_leaf':16,
          'min_samples_split':16
          }

# %%
from sklearn.ensemble import GradientBoostingRegressor
y=df['Survived']
x=df[['SibSp','Pclass','Fare']]
gbr = GradientBoostingRegressor(**params)
gbr.fit(x,y)
# Out:
# GradientBoostingRegressor(criterion='mse', learning_rate=0.03, max_depth=12,
#                           min_samples_leaf=16, min_samples_split=16,
#                           n_estimators=200)

# %%
gbr.score(x,y)
# Out:
# 0.3514214757309715
